# %% [markdown]
# <a href="https://colab.research.google.com/github/Nogueira-Amanda/Estrutura_Dados_II/blob/main/HeapSort_Sortia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
"""Jogo didático de Heapsort para execução no terminal.

O estudante constrói uma max-heap e depois executa o Heapsort escolhendo
manualmente as trocas. O programa valida cada decisão e explica os índices.
Não usa bibliotecas externas.
"""

from __future__ import annotations

import random
from dataclasses import dataclass


@dataclass
class Placar:
    acertos: int = 0
    erros: int = 0
    dicas: int = 0

    @property
    def pontos(self) -> int:
        return max(0, self.acertos * 10 - self.erros * 2 - self.dicas)


def filhos(indice: int, tamanho: int) -> list[int]:
    """Retorna os índices dos filhos existentes de um nó."""
    candidatos = (2 * indice + 1, 2 * indice + 2)
    return [i for i in candidatos if i < tamanho]


def maior_filho(vetor: list[int], indice: int, tamanho: int) -> int | None:
    """Retorna o índice do maior filho, priorizando o esquerdo em empate."""
    indices = filhos(indice, tamanho)
    return max(indices, key=lambda i: vetor[i]) if indices else None


def tem_propriedade_heap(vetor: list[int], indice: int, tamanho: int) -> bool:
    """Verifica a propriedade de max-heap em um nó."""
    return all(vetor[indice] >= vetor[f] for f in filhos(indice, tamanho))


def eh_max_heap(vetor: list[int], tamanho: int) -> bool:
    """Verifica se o prefixo vetor[:tamanho] é uma max-heap."""
    return all(tem_propriedade_heap(vetor, i, tamanho) for i in range(tamanho // 2))


def exibir_arvore(vetor: list[int], tamanho_heap: int) -> None:
    """Mostra a heap por níveis e separa a região já ordenada."""
    print("\nVetor:", " ".join(f"[{i}:{v}]" for i, v in enumerate(vetor)))
    print("Heap ativa:", vetor[:tamanho_heap], "| Ordenados:", vetor[tamanho_heap:])
    if tamanho_heap == 0:
        return
    print("Árvore lógica (índice:valor):")
    inicio, largura = 0, 1
    while inicio < tamanho_heap:
        fim = min(inicio + largura, tamanho_heap)
        print("  " + "   ".join(f"{i}:{vetor[i]}" for i in range(inicio, fim)))
        inicio, largura = fim, largura * 2


def ler_escolha(prompt: str, opcoes: set[str]) -> str:
    while True:
        resposta = input(prompt).strip().lower()
        if resposta in opcoes:
            return resposta
        print("Opção inválida. Escolha:", ", ".join(sorted(opcoes)))


def perguntar_troca(
    vetor: list[int], indice_pai: int, indice_filho: int, placar: Placar
) -> None:
    """Solicita a troca correta entre pai e maior filho."""
    while True:
        print(f"O nó {indice_pai}:{vetor[indice_pai]} viola a propriedade de max-heap.")
        resposta = input(
            "Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': "
        ).strip().lower()
        if resposta == "dica":
            placar.dicas += 1
            print(
                "Dica: compare os dois filhos e troque o pai com o filho de maior valor."
            )
            continue
        try:
            a, b = map(int, resposta.split())
        except ValueError:
            print("Informe exatamente dois índices inteiros.")
            continue
        if {a, b} == {indice_pai, indice_filho}:
            vetor[indice_pai], vetor[indice_filho] = vetor[indice_filho], vetor[indice_pai]
            placar.acertos += 1
            print("✓ Troca correta!")
            return
        placar.erros += 1
        print("✗ Essa troca não restaura a propriedade de heap neste nó. Tente novamente.")


def descer_manual(vetor: list[int], raiz: int, tamanho: int, placar: Placar) -> None:
    """Restaura a heap, exigindo que o estudante escolha cada troca."""
    pai = raiz
    while True:
        filho = maior_filho(vetor, pai, tamanho)
        if filho is None or vetor[pai] >= vetor[filho]:
            print(f"O nó {pai}:{vetor[pai]} já possui a propriedade de heap.")
            return
        exibir_arvore(vetor, tamanho)
        perguntar_troca(vetor, pai, filho, placar)
        pai = filho


def construir_heap(vetor: list[int], placar: Placar) -> None:
    print("\n=== FASE 1 — CONSTRUIR A MAX-HEAP ===")
    print("Percorreremos os pais de baixo para cima.")
    for pai in range(len(vetor) // 2 - 1, -1, -1):
        print(f"\nAnalisando o nó de índice {pai}...")
        descer_manual(vetor, pai, len(vetor), placar)
    assert eh_max_heap(vetor, len(vetor))
    exibir_arvore(vetor, len(vetor))
    print("✓ Max-heap construída: o maior valor está na raiz.")


def ordenar_manual(vetor: list[int], placar: Placar) -> None:
    print("\n=== FASE 2 — ORDENAR ===")
    for fim in range(len(vetor) - 1, 0, -1):
        exibir_arvore(vetor, fim + 1)
        print("A raiz contém o maior valor da heap ativa.")
        while True:
            resposta = input(
                f"Quais índices devem ser trocados para fixar o máximo na posição {fim}? "
            ).strip().lower()
            if resposta == "dica":
                placar.dicas += 1
                print(f"Dica: troque a raiz (índice 0) com o último índice ativo ({fim}).")
                continue
            try:
                a, b = map(int, resposta.split())
            except ValueError:
                print("Digite dois índices ou 'dica'.")
                continue
            if {a, b} == {0, fim}:
                vetor[0], vetor[fim] = vetor[fim], vetor[0]
                placar.acertos += 1
                print("✓ Máximo colocado em sua posição definitiva!")
                break
            placar.erros += 1
            print("✗ A troca deve retirar a raiz e reduzir a heap ativa.")
        descer_manual(vetor, 0, fim, placar)


def obter_vetor() -> list[int]:
    print("\n1 — Usar números aleatórios")
    print("2 — Digitar os números")
    escolha = ler_escolha("Escolha: ", {"1", "2"})
    if escolha == "1":
        return random.sample(range(1, 100), 7)
    while True:
        try:
            valores = [int(x) for x in input("Digite de 4 a 12 inteiros separados por espaço: ").split()]
            if 4 <= len(valores) <= 12:
                return valores
        except ValueError:
            pass
        print("Entrada inválida. Use somente inteiros e informe entre 4 e 12 valores.")


def main() -> None:
    print("=" * 58)
    print("JOGO DE HEAPSORT — APRENDER FAZENDO")
    print("=" * 58)
    print("Em um vetor com índice i: esquerdo = 2i+1; direito = 2i+2.")
    print("Regra da max-heap: todo pai deve ser maior ou igual aos filhos.")
    vetor = obter_vetor()
    original = vetor.copy()
    placar = Placar()
    construir_heap(vetor, placar)
    ordenar_manual(vetor, placar)
    exibir_arvore(vetor, 0)
    assert vetor == sorted(original)
    print("\nParabéns! Ordenação concluída.")
    print("Original:", original)
    print("Ordenado:", vetor)
    print(
        f"Placar: {placar.pontos} pontos "
        f"({placar.acertos} acertos, {placar.erros} erros, {placar.dicas} dicas)"
    )


if __name__ == "__main__":
    main()
# Out:
# ==========================================================
# JOGO DE HEAPSORT — APRENDER FAZENDO
# ==========================================================
# Em um vetor com índice i: esquerdo = 2i+1; direito = 2i+2.
# Regra da max-heap: todo pai deve ser maior ou igual aos filhos.
#
# 1 — Usar números aleatórios
# 2 — Digitar os números
# Escolha: 2
# Digite de 4 a 12 inteiros separados por espaço: 88 59 26 86 70 33 32
#
# === FASE 1 — CONSTRUIR A MAX-HEAP ===
# Percorreremos os pais de baixo para cima.
#
# Analisando o nó de índice 2...
#
# Vetor: [0:88] [1:59] [2:26] [3:86] [4:70] [5:33] [6:32]
# Heap ativa: [88, 59, 26, 86, 70, 33, 32] | Ordenados: []
# Árvore lógica (índice:valor):
#   0:88
#   1:59   2:26
#   3:86   4:70   5:33   6:32
# O nó 2:26 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 5 2
# ✓ Troca correta!
# O nó 5:26 já possui a propriedade de heap.
#
# Analisando o nó de índice 1...
#
# Vetor: [0:88] [1:59] [2:33] [3:86] [4:70] [5:26] [6:32]
# Heap ativa: [88, 59, 33, 86, 70, 26, 32] | Ordenados: []
# Árvore lógica (índice:valor):
#   0:88
#   1:59   2:33
#   3:86   4:70   5:26   6:32
# O nó 1:59 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 1 3
# ✓ Troca correta!
# O nó 3:59 já possui a propriedade de heap.
#
# Analisando o nó de índice 0...
# O nó 0:88 já possui a propriedade de heap.
#
# Vetor: [0:88] [1:86] [2:33] [3:59] [4:70] [5:26] [6:32]
# Heap ativa: [88, 86, 33, 59, 70, 26, 32] | Ordenados: []
# Árvore lógica (índice:valor):
#   0:88
#   1:86   2:33
#   3:59   4:70   5:26   6:32
# ✓ Max-heap construída: o maior valor está na raiz.
#
# === FASE 2 — ORDENAR ===
#
# Vetor: [0:88] [1:86] [2:33] [3:59] [4:70] [5:26] [6:32]
# Heap ativa: [88, 86, 33, 59, 70, 26, 32] | Ordenados: []
# Árvore lógica (índice:valor):
#   0:88
#   1:86   2:33
#   3:59   4:70   5:26   6:32
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 6? 0 6
# ✓ Máximo colocado em sua posição definitiva!
#
# Vetor: [0:32] [1:86] [2:33] [3:59] [4:70] [5:26] [6:88]
# Heap ativa: [32, 86, 33, 59, 70, 26] | Ordenados: [88]
# Árvore lógica (índice:valor):
#   0:32
#   1:86   2:33
#   3:59   4:70   5:26
# O nó 0:32 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 0 1
# ✓ Troca correta!
#
# Vetor: [0:86] [1:32] [2:33] [3:59] [4:70] [5:26] [6:88]
# Heap ativa: [86, 32, 33, 59, 70, 26] | Ordenados: [88]
# Árvore lógica (índice:valor):
#   0:86
#   1:32   2:33
#   3:59   4:70   5:26
# O nó 1:32 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 4 1
# ✓ Troca correta!
# O nó 4:32 já possui a propriedade de heap.
#
# Vetor: [0:86] [1:70] [2:33] [3:59] [4:32] [5:26] [6:88]
# Heap ativa: [86, 70, 33, 59, 32, 26] | Ordenados: [88]
# Árvore lógica (índice:valor):
#   0:86
#   1:70   2:33
#   3:59   4:32   5:26
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 5? 0 5
# ✓ Máximo colocado em sua posição definitiva!
#
# Vetor: [0:26] [1:70] [2:33] [3:59] [4:32] [5:86] [6:88]
# Heap ativa: [26, 70, 33, 59, 32] | Ordenados: [86, 88]
# Árvore lógica (índice:valor):
#   0:26
#   1:70   2:33
#   3:59   4:32
# O nó 0:26 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 0 1
# ✓ Troca correta!
#
# Vetor: [0:70] [1:26] [2:33] [3:59] [4:32] [5:86] [6:88]
# Heap ativa: [70, 26, 33, 59, 32] | Ordenados: [86, 88]
# Árvore lógica (índice:valor):
#   0:70
#   1:26   2:33
#   3:59   4:32
# O nó 1:26 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 1 3
# ✓ Troca correta!
# O nó 3:26 já possui a propriedade de heap.
#
# Vetor: [0:70] [1:59] [2:33] [3:26] [4:32] [5:86] [6:88]
# Heap ativa: [70, 59, 33, 26, 32] | Ordenados: [86, 88]
# Árvore lógica (índice:valor):
#   0:70
#   1:59   2:33
#   3:26   4:32
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 4? 0 4
# ✓ Máximo colocado em sua posição definitiva!
#
# Vetor: [0:32] [1:59] [2:33] [3:26] [4:70] [5:86] [6:88]
# Heap ativa: [32, 59, 33, 26] | Ordenados: [70, 86, 88]
# Árvore lógica (índice:valor):
#   0:32
#   1:59   2:33
#   3:26
# O nó 0:32 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 0 1
# ✓ Troca correta!
# O nó 1:32 já possui a propriedade de heap.
#
# Vetor: [0:59] [1:32] [2:33] [3:26] [4:70] [5:86] [6:88]
# Heap ativa: [59, 32, 33, 26] | Ordenados: [70, 86, 88]
# Árvore lógica (índice:valor):
#   0:59
#   1:32   2:33
#   3:26
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 3? 0 3
# ✓ Máximo colocado em sua posição definitiva!
#
# Vetor: [0:26] [1:32] [2:33] [3:59] [4:70] [5:86] [6:88]
# Heap ativa: [26, 32, 33] | Ordenados: [59, 70, 86, 88]
# Árvore lógica (índice:valor):
#   0:26
#   1:32   2:33
# O nó 0:26 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 0 2
# ✓ Troca correta!
# O nó 2:26 já possui a propriedade de heap.
#
# Vetor: [0:33] [1:32] [2:26] [3:59] [4:70] [5:86] [6:88]
# Heap ativa: [33, 32, 26] | Ordenados: [59, 70, 86, 88]
# Árvore lógica (índice:valor):
#   0:33
#   1:32   2:26
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 2? 0 2
# ✓ Máximo colocado em sua posição definitiva!
#
# Vetor: [0:26] [1:32] [2:33] [3:59] [4:70] [5:86] [6:88]
# Heap ativa: [26, 32] | Ordenados: [33, 59, 70, 86, 88]
# Árvore lógica (índice:valor):
#   0:26
#   1:32
# O nó 0:26 viola a propriedade de max-heap.
# Digite os índices que devem ser trocados (ex.: 1 4) ou 'dica': 0 1
# ✓ Troca correta!
# O nó 1:26 já possui a propriedade de heap.
#
# Vetor: [0:32] [1:26] [2:33] [3:59] [4:70] [5:86] [6:88]
# Heap ativa: [32, 26] | Ordenados: [33, 59, 70, 86, 88]
# Árvore lógica (índice:valor):
#   0:32
#   1:26
# A raiz contém o maior valor da heap ativa.
# Quais índices devem ser trocados para fixar o máximo na posição 1? 0 1
# ✓ Máximo colocado em sua posição definitiva!
# O nó 0:26 já possui a propriedade de heap.
#
# Vetor: [0:26] [1:32] [2:33] [3:59] [4:70] [5:86] [6:88]
# Heap ativa: [] | Ordenados: [26, 32, 33, 59, 70, 86, 88]
#
# Parabéns! Ordenação concluída.
# Original: [88, 59, 26, 86, 70, 33, 32]
# Ordenado: [26, 32, 33, 59, 70, 86, 88]
# Placar: 150 pontos (15 acertos, 0 erros, 0 dicas)
